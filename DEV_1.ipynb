# %% [markdown]
# <a href="https://colab.research.google.com/github/akshayasakthi02/DEV-LAB/blob/main/DEV_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data (you can replace this with your own dataset)
data = {
    'Name': ['John', 'Jane', 'Mike', 'Emily', 'Alex'],
    'Age': [25, 30, 22, 28, 35],
    'Score': [90, 85, 78, 95, 88]
}

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Display the DataFrame
print("DataFrame:")
print(df)

# Data Analysis
print("\nData Analysis:")
print("Mean Age:", df['Age'].mean())
print("Maximum Score:", df['Score'].max())
print("Minimum Score:", df['Score'].min())

# Data Visualization
plt.figure(figsize=(8, 4))
plt.bar(df['Name'], df['Score'], color='skyblue')
plt.xlabel('Name')
plt.ylabel('Score')
plt.title('Scores of Students')
plt.tight_layout()
plt.show()
# Out:
# DataFrame:
#     Name  Age  Score
# 0   John   25     90
# 1   Jane   30     85
# 2   Mike   22     78
# 3  Emily   28     95
# 4   Alex   35     88
#
# Data Analysis:
# Mean Age: 28.0
# Maximum Score: 95
# Minimum Score: 78
